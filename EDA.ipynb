# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('OLX_cars_dataset00.csv')

# %%
print(df.describe())
# Out:
#               Ad ID         Year    KM's driven         Price
# count  9.179000e+03  9179.000000    9179.000000  9.179000e+03
# mean   1.079720e+09  2012.268984   96570.420525  2.036814e+06
# std    2.848393e+06     6.043902   61983.250088  1.159302e+06
# min    1.019824e+09  1989.000000       1.000000  1.850000e+05
# 25%    1.080003e+09  2007.000000   53000.000000  1.025000e+06
# 50%    1.080543e+09  2013.000000   92000.000000  1.820000e+06
# 75%    1.080773e+09  2017.000000  125000.000000  2.750000e+06
# max    1.080975e+09  2024.000000  533528.000000  5.000000e+06

# %%
print(df.shape)
# Out:
# (9179, 18)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of            Ad ID                                     Car Name      Make  \
# 0     1079071571                 fresh import Passo 2021model    Toyota
# 1     1080125520                                  Suzuki ravi    Suzuki
# 2     1080748789        Suzuki bolan 2015 contact 03112271054    Suzuki
# 3     1076081635                           Diahatsu Move 2013  Daihatsu
# 4     1080812928           Suzuki Swift DLX 2011 miner tuchap    Suzuki
# ...          ...                                          ...       ...
# 9174  1080606577  Suzuki Wagon R Japanese 660cc sale/exchange    Suzuki
# 9175  1080268395                             wegon R VXL 2017    Suzuki
# 9176  1080570925                               Good condition       KIA
# 9177  1075792717                              Suzuki Alto vxr    Suzuki
# 9178  1080569552                                  Move Custom  Daihatsu
#
#         Model  Year  KM's driven    Price    Fuel Registration city  \
# 0       Passo  2021        54000  4190000  Petrol      Unregistered
# 1        Ravi  2018        95000  1300000  Petrol           Karachi
# 2       Bolan  2015        50000   800000  Petrol           Karachi
# 3        Move  2013        94000  2155000  Petrol            Lahore
# 4       Swift  2011       126544  1440000  Petrol           Karachi
# ...       ...   ...          ...      ...     ...               ...
# 9174  Wagon R  2014       115000  2725000  Petrol         Islamabad
# 9175  Wagon R  2017       100000  1850000  Petrol            Lahore
# 9176  Spectra  2001       123456  1100000  Petrol            Lahore
# 9177     Alto  2009        89000   970000  Petrol            Lahore
# 9178     Move  2016        95000  2050000  Petrol        Gujranwala
#
#      Car documents  Assembly Transmission Condition  \
# 0         Original  Imported    Automatic      Used
# 1         Original     Local       Manual      Used
# 2         Original     Local       Manual      Used
# 3         Original  Imported    Automatic      Used
# 4         Original     Local       Manual      Used
# ...            ...       ...          ...       ...
# 9174      Original  Imported    Automatic      Used
# 9175      Original     Local       Manual      Used
# 9176      Original  Imported    Automatic      Used
# 9177      Original  Imported       Manual      Used
# 9178      Original  Imported    Automatic      Used
#
#                           Seller Location  \
# 0               Airline Avenue, Islamabad
# 1                      Kahuta, Rawalpindi
# 2               Lyari Expressway, Karachi
# 3                   New Amir Town, Lahore
# 4                      Shadman 2, Karachi
# ...                                   ...
# 9174                      G-13, Islamabad
# 9175         New Satellite Town, Sargodha
# 9176                Wahdat Colony, Taxila
# 9177  Yar Hussain - Chota Lahor Rd, Swabi
# 9178        Gujranwala Bypass, Gujranwala
#
#                                             Description  \
# 0     it's 2021 model fresh import, perfect engine s...
# 1                                 Suzuki ravi 2018 col
# 2     Suzuki bolan model 2015 reg 2022 ghadi me koi ...
# 3     Move Push start \nHome Used car. \nModel 2013....
# 4     Suzuki Swift DLX\nAbS Break 100%\nengine 100%\...
# ...                                                 ...
# 9174  Japanese Wagon R 2014 Full automatic option Re...
# 9175  wegon r vxl 2017 model 2 piece touch Ac on new...
# 9176                      karobar may invest karna  hay
# 9177  Suzuki Alto Vxr \nAC, HEATER INSTALLED\nCNG, P...
# 9178  sides shower \n23 average feul\nmy own registe...
#
#                                            Car Features  \
# 0     ABS, Air Bags, AM/FM Radio, CD Player, Cassett...
# 1                                           AM/FM Radio
# 2                                         Rear speakers
# 3     ABS, Air Bags, Air Conditioning, Alloy Rims, A...
# 4     ABS, Air Conditioning, Alloy Rims, AM/FM Radio...
# ...                                                 ...
# 9174  ABS, Air Bags, Air Conditioning, Alloy Rims, A...
# 9175  Air Conditioning, CD Player, Power Steering, P...
# 9176  Air Conditioning, AM/FM Radio, DVD Player, Pow...
# 9177  Air Conditioning, AM/FM Radio, Front Speakers,...
# 9178  ABS, Air Bags, Air Conditioning, Alloy Rims, A...
#
#                                            Images URL's  \
# 0     ['https://images.olx.com.pk/thumbnails/4039460...
# 1     ['https://images.olx.com.pk/thumbnails/4102504...
# 2     ['https://images.olx.com.pk/thumbnails/4139520...
# 3     ['https://images.olx.com.pk/thumbnails/3865337...
# 4     ['https://images.olx.com.pk/thumbnails/4143509...
# ...                                                 ...
# 9174  ['https://images.olx.com.pk/thumbnails/4131117...
# 9175  ['https://images.olx.com.pk/thumbnails/4111048...
# 9176  ['https://images.olx.com.pk/thumbnails/4129002...
# 9177  ['https://images.olx.com.pk/thumbnails/3848969...
# 9178  ['https://images.olx.com.pk/thumbnails/4128920...
#
#                                             Car Profile
# 0     https://www.olx.com.pk/item/fresh-import-passo...
# 1     https://www.olx.com.pk/item/suzuki-ravi-iid-10...
# 2     https://www.olx.com.pk/item/suzuki-bolan-2015-...
# 3     https://www.olx.com.pk/item/diahatsu-move-2013...
# 4     https://www.olx.com.pk/item/suzuki-swift-dlx-2...
# ...                                                 ...
# 9174  https://www.olx.com.pk/item/suzuki-wagon-r-jap...
# 9175  https://www.olx.com.pk/item/wegon-r-vxl-2017-i...
# 9176  https://www.olx.com.pk/item/good-condition-iid...
# 9177  https://www.olx.com.pk/item/suzuki-alto-vxr-ii...
# 9178  https://www.olx.com.pk/item/move-custom-iid-10...
#
# [9179 rows x 18 columns]>

# %%
print(df.hist(figsize=(10,15)))
# Out:
# [[<Axes: title={'center': 'Ad ID'}> <Axes: title={'center': 'Year'}>]
#  [<Axes: title={'center': "KM's driven"}>
#   <Axes: title={'center': 'Price'}>]]

# %%
df.value_counts("Car Name")
# Out:
# Car Name
# Honda City                                                       33
# Suzuki Bolan                                                     28
# Honda city                                                       23
# Suzuki bolan                                                     23
# urgent sale                                                      19
#                                                                  ..
# Honda city gift for city lovers what's app number 03176688398     1
# Honda city for sell haronbad                                      1
# Honda city for sell                                               1
# Honda city for sale.                                              1
# ہنڈائ سنٹرو کلب اندر سے جیوین باہر سے ٹیچنگ ے ہلکی پھلکی          1
# Name: count, Length: 7970, dtype: int64

# %%
plt.scatter(df["Year"],df["Price"])
